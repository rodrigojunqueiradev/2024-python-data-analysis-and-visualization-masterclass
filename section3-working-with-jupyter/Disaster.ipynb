# %%
while True:
    print("HI")
# Out:
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# ...
